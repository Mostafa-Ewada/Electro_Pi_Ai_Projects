# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
#/content/drive/My Drive/International_Report_Departures.csv
File_Name = input('Enter file path : ')
N_Columns = int(input('How many columns you want '))

File_Extension = File_Name.split('.')[-1]


if File_Extension == 'csv' :
  df = pd.read_csv(File_Name)
elif File_Extension == 'json' :
  df = pd.read_json(File_Name)
elif File_Extension == 'db' :
  df = pd.read_sql_query(File_Name)
elif File_Extension == 'txt' :
  with open(File_Name, 'r') as file :
    df = file.read()
else :
  print('Invalid File Extension')

df = df.iloc[:, : N_Columns]
df_columns = df.columns
df_types = df.dtypes
df = df.dropna()

for i in list(df.columns) :
  counts = df[i].value_counts()
  counts = pd.DataFrame(counts)
  plt.bar(counts.T.columns, counts[i])
  plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter file path : /content/drive/My Drive/International_Report_Departures.csv
# How many columns you want 3
